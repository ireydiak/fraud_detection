# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from collections import Counter
from imblearn.over_sampling import SMOTE

dataset_fname = "QSAR_dataset.xlsx"
test_fname = "test_TP1.xlsx"

# %% [markdown]
# # 1- Représentation des données
# Dans cette étape, nous devons:
# - analyser chaque attribut;
# - proposer un prétraitement des données;
# - sélectionner les 10 meilleurs attributs avec justification statistique;
# - visualiser la distribution des 10 meilleurs attributs.
#
# Commençon par charger les données.
#
# ### Chargement des données

# %%
# Chargement des données d'entraînement
df = pd.read_excel(dataset_fname, index_col=0)
# Lecture rapide des cinq premières entrées pour valider le chargement adéquat des données
df.head(5)
# Out:
#                                                        Class       apol  \
# SMILES
# FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)...   Class 2  41.283001
# c12c(cccc1)cccc2                                     Class 2  22.934343
# Clc1c(Cl)c(Cl)c(c(Cl)c1Cl)-c1c(Cl)c(Cl)c(Cl)c(C...  Class -2  42.919998
# ClC1(Cl)C2(Cl)C(Cl)=C(Cl)C1(Cl)C1C2C(Cl)C2(Cl)OC12  Class -2  38.509171
# Clc1c(Cl)c(Cl)c(c(Cl)c1Cl)-c1c(Cl)c(Cl)c(Cl)c(C...  Class -2  41.406792
#
#                                                           ASA+       ASA-  \
# SMILES
# FC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)...   21.282999  622.40619
# c12c(cccc1)cccc2                                    155.975430  156.69504
# Clc1c(Cl)c(Cl)c(c(Cl)c1Cl)-c1c(Cl)c(Cl)c(Cl)c(C...   38.976181  499.52170
# ClC1(Cl)C2(Cl)C(Cl)=C(Cl)C1(Cl)C1C2C(Cl)C2(Cl)OC12   46.270092  421.43369
# Clc1c(Cl)c(Cl)c(c(Cl)c1Cl)-c1c(Cl)c(Cl)c(Cl)c(C...   56.392834  480.49115
#
# ...

# %% [markdown]
# ## Analyser chaque attribut
#
# Dans cette étape, nous analyserons chacun des attributs. D'abord, nous déterminons les types (catégories, ordinales, cycliques, quantitatifs, etc.) des nos données avant de filter les valeurs aberrantes ou manquantes. Finalement, nous procéderons à une analyse statistique primaire (moyenne, variance, équart-type, etc.) des attributs.
#
# #### Attributs quantitatifs et qualitatifs
# D'abord, distinguons les attributs qualitatifs des attributs quantitatifs. Nous portons une attention particulière aux attributs qualitatifs (ou catégoriques) car ceux-ci nécessitent du pré-traitement particulier.

# %%
num_cols = df.select_dtypes(exclude=["object", "category"]).columns.tolist()
cat_cols = df.select_dtypes(include=["category", "object"]).columns.tolist()
print("Nombre d'attributs numériques: {}".format(len(num_cols)))
print("Nombre d'attributs catégoriques: {}".format(len(cat_cols)))
if len(cat_cols) > 0:
    print(cat_cols)
# Out:
# Nombre d'attributs numériques: 74
# Nombre d'attributs catégoriques: 1
# ['Class']

# %% [markdown]
# Seul l'attribut `Class` est catégorique, ce qui est normal puisqu'il associe une classe à chacune des observations. Tous nos attributs sont donc numériques, ce qui facilitera grandement notre prétraitement.

# %% [markdown]
# #### Valeurs uniques et doublons
# Finalement, nous devons considérons les valeurs uniques. Celles-ci ne sont pas techniquement invalides, mais peuvent néamoins être ignorées car elles ne contribueront pas à la décision des algorithmes. On pourrait supprimer les lignes invalides, mais considérant la taille des données (environ 200 observations), une telle stratégie évacuerait trop de données pertinentes. Nous discuterons d'une stratégie plus loin.

# %%
uniq_cols = df.columns[df.nunique() == 1]
uniq_cols
# Out:
# Index([], dtype='object')

# %% [markdown]
# La liste `uniq_cols` est vide, ce qui implique que tous les attributs possèdent plusieurs valeurs distinctes. Vérifions maintenant s'il existe des doublons dans les données et supprimons les.

# %%
n_duplicated_rows = df.duplicated().sum()
df = df.drop_duplicates()
print("Lignes supprimées: {}".format(n_duplicated_rows))
print("Ratio: {:.4f}".format(n_duplicated_rows / len(df)))
assert df.duplicated().sum() == 0, "Erreur: il reste des doublons dans les données"
# Out:
# Lignes supprimées: 22
# Ratio: 0.1667

# %% [markdown]
# #### Valeurs aberrantes
# Maintenant, détectons les valeurs abberantes ou invalides (`NaN`, `±inf`, etc.). Dans notre traitement, nous commençons par convertir les valeurs `±inf` en `NaN` car celles-ci seront traitées de la même manière.

# %%
df = df.replace([-np.inf, np.inf], np.nan)
nan_cols = df.columns[df.isna().any()]
nan_summary = df[nan_cols].isna().sum().sort_values(ascending=False)
nan_ratio = nan_summary / len(df)
nan_df = pd.concat((nan_summary, nan_ratio), axis=1)
nan_df = nan_df.rename(columns={0: "Count", 1: "Ratio"})
print(nan_df)
# Out:
#          Count     Ratio
# vsurf_V     16  0.121212
# vsurf_S     12  0.090909
# vsurf_R      7  0.053030
# ASA+         2  0.015152
# ASA-         1  0.007576
# a_heavy      1  0.007576
# a_IC         1  0.007576

# %% [markdown]
# On constate que les variables `vsurf_V` et `vsurf_S` contiennent beaucoup de valeurs manquates (12.12% et 9.09% respectivement). Par contraste, `ASA+`, `ASA-`, `a_heavy` et `a_IC` contiennent seulement entre 1 et 2 observations invalides. Nous verrons plus tard comment traiter ces données.

# %% [markdown]
# #### Analyse statistique
# On peut maintenant extraire certaines statistiques de base pour tous les attributs.

# %%
df_describe = df.describe()
df_describe
# Out:
#              apol        ASA+        ASA-     a_count    a_donacc     a_heavy  \
# count  132.000000  130.000000  131.000000  132.000000  132.000000  131.000000
# mean    34.584853  108.411883  355.786246   23.803030    0.340909   18.633588
# std      6.166294   62.988950  114.675033    5.021236    0.923233    5.644883
# min     17.148172    8.778115  122.917570   12.000000    0.000000   10.000000
# 25%     31.307930   69.558443  299.823835   22.000000    0.000000   16.000000
# 50%     35.681965   99.001797  380.565190   22.000000    0.000000   18.000000
# 75%     38.549388  141.947095  427.294460   24.250000    0.000000   19.000000
# max     52.422001  356.764860  622.904600   43.000000    4.000000   43.000000
#
#             a_hyd        a_IC        a_nC       a_nCl  ...         VSA  \
# count  132.000000  131.000000  132.000000  132.000000  ...  132.000000
# mean    17.090909   33.887930   11.590909    3.083333  ...  272.305850
# ...

# %% [markdown]
# Cette analyse primaire nous indique que les différentes variables respectent des échelles de grandeur très différentes. Par exemple, `apol` $\in [17, 53]$ tandis que `vsurf_R` $\in [-6.8\mathrm{e+}08, 1.61\mathrm{e-}01]$. Nous devons donc centrer et réduire les données sans quoi non seulement l'analyse en composantes principales sera invalide, mais notre modèle de classification sera peut-être biaisé par les attributs avec de très grandes valeurs.
#
# Avant de procéder, nous devons gérer les données manquates identifiées précedemment. Commençons par afficher toutes les lignes invalides.

# %%
df[df.isna().any(axis=1)]
# Out:
#                                                        Class       apol  \
# SMILES
# O=C(Oc1c2OC(C)(C)Oc2ccc1)NC                          Class 0  32.336308
# S(=O)(=O)([O-])C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)...  Class -1  28.855000
# Clc1c(Cl)c(-c2c(Cl)cc(Cl)c(Cl)c2)cc(Cl)c1[O-]        Class 0  37.002380
# Brc1c(Br)cc(Oc2c(Br)cc(Br)cc2)c(Br)c1               Class -1  40.505966
# Clc1c(Cl)cc(c(Cl)c1)-c1c(Cl)cc(Cl)cc1               Class -1  35.353966
# ClC(Cl)C(c1c(Cl)cccc1)c1ccc(Cl)cc1                  Class -1  40.027931
# Clc1c(Cl)c(Cl)c2c(c1Cl)oc1c(Cl)c(Cl)c(Cl)cc21       Class -1  37.848793
# S(=O)(=O)([O-])C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)...  Class -1  23.107000
# Clc1c(Cl)c(c(Cl)c(Cl)c1[O-])-c1c(Cl)cc(Cl)c(Cl)c1    Class 0  38.515587
# Clc1c(Cl)c(-c2c(Cl)cc(Cl)c(Cl)c2)cc(Cl)c1[O-]        Class 0  37.002380
# Clc1c(Cl)c(-c2c(Cl)cc(Cl)c(Cl)c2)cc(Cl)c1[O-]        Class 0  37.002380
# Clc1c(Cl)c(-c2c(Cl)cc(Cl)c(Cl)c2)cc(Cl)c1[O-]        Class 0  37.002380
# ...

# %% [markdown]
# On constate que les valeurs invalides pour `ASA-`, `a_heavy` et `a_IC` se trouvent toutes sur des lignes distinctes. Si elles étaient toutes associées à la même ligne, nous aurions pu simplement supprimer cette ligne et perdre moins de 1% des données. Puisque nous possédons seulement  $n=154$ observations, les stratégies d'ablation sont rejetées par défaut. Une stratégie alternative consiste à remplacer les valeurs manquantes par une valeur bien représentative. Ainsi, ré-affichons les statistiques élémentaires pour les colonnes invalides seulement.

# %%
df[nan_cols].describe()
# Out:
#              ASA+        ASA-     a_heavy        a_IC       vsurf_R  \
# count  130.000000  131.000000  131.000000  131.000000  1.250000e+02
# mean   108.411883  355.786246   18.633588   33.887930 -8.000000e+08
# std     62.988950  114.675033    5.644883   10.360759  8.944272e+09
# min      8.778115  122.917570   10.000000   12.000000 -1.000000e+11
# 25%     69.558443  299.823835   16.000000   29.348074  2.629501e-01
# 50%     99.001797  380.565190   18.000000   31.868664  7.939334e-01
# 75%    141.947095  427.294460   19.000000   37.512600  9.767328e+00
# max    356.764860  622.904600   43.000000   86.319427  1.611555e+01
#
#           vsurf_S     vsurf_V
# count  120.000000  116.000000
# mean   -62.631951   -2.303986
# std     70.510090    2.643785
# min   -209.769584   -8.247237
# 25%   -128.674633   -4.829376
# 50%    -10.620018   -0.387075
# 75%     -3.386326   -0.128133
# max     -0.338738   -0.013318

# %%
fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(12,8))

axs[0, 0].set_title("ASA+")
axs[0, 1].set_title("ASA-")
axs[0, 2].set_title("a_heavy")
axs[1, 0].set_title("a_IC")
axs[1, 1].set_title("vsurf_R")
axs[1, 2].set_title("vsurf_S")
axs[2, 0].set_title("vsurf_V")
sns.kdeplot(df[["ASA+"]].to_numpy().reshape(-1), ax=axs[0, 0])
sns.kdeplot(df[["ASA-"]].to_numpy().reshape(-1), ax=axs[0, 1])
sns.kdeplot(df[["a_heavy"]].to_numpy().reshape(-1), ax=axs[0, 2])
sns.kdeplot(df[["a_IC"]].to_numpy().reshape(-1), ax=axs[1, 0])
sns.kdeplot(df[["vsurf_R"]].to_numpy().reshape(-1), ax=axs[1, 1])
sns.kdeplot(df[["vsurf_S"]].to_numpy().reshape(-1), ax=axs[1, 2])

sns.kdeplot(df[["vsurf_V"]].to_numpy().reshape(-1), ax=axs[2, 0])

plt.tight_layout()
plt.show()

# %% [markdown]
# Les diagrammes de densité nous indique que la distribution des variables `a_heavy`, `a_IC` et `vsurf_R` sont plutôt concentrées autour de leur moyenne respective. On peut donc remplacer les valeurs manquantes par la moyenne sans altérer la distribution ou introduire un biais ayant un impact significatif dans la tâche de classification. Pour les autres attributs, c'est-à-dire `ASA+`, `ASA-`, `vsurf_S` et `vsurf_V` , on utilise plutôt la valeur médiane.

# %%
# Remplacement des valeurs manquantes par la moyenne pour les attributs
# `a_heavy`, `a_IC` et `vsurf_R`.
for col in ["a_heavy", "a_IC", "vsurf_R"]:
    df.loc[:, col].fillna(df.loc[:, col].mean(), inplace=True)

# Remplacement des valeurs manquantes par la médiane pour les autres attributs restants
for col in set(nan_cols) - set(["a_heavy", "a_IC", "vsurf_R"]):
    df.loc[:, col].fillna(df.loc[:, col].median(), inplace=True)

# On valide la dernière opération en s'assurant qu'il ne reste aucun attribut avec des 
# valeurs manquates dans les données
n_remaining_nan = df.isna().sum().sum()
assert n_remaining_nan == 0, "Il reste {} valeurs manquantes".format(n_remaining_nan)

# %% [markdown]
# ## Débalancement de classe
# Les données présentent un fort débalancement dans les classes. Certaines classes sont beaucoup plus nombreuses que d'autres.

# %%
df["Class"].explode().value_counts()
# Out:
# Class -1    56
# Class 0     48
# Class 1     20
# Class -2     6
# Class 2      2
# Name: Class, dtype: int64

# %% [markdown]
# En effet, la classe 2 possède seulement deux observations tandis que la classe -1 en possède plutôt 56. On utilise l'algorithme SMOTE pour ré-équilibrer le tout. On doit être prudent en utilisant cette technique car on peut créer des clusters artificiels qui ne reflètent pas nécessairement la réalité empirique. On ré-équilibre donc les classes -2 et 1 en fonction de la classe 0. Nous devons malheureusement ignorer la classe 2 car elle ne contient pas assez de données.

# %%
sm = SMOTE(
    random_state=42,
    sampling_strategy={"Class 1": 48, "Class -2": 48}
)
X, y = df.loc[:, df.columns != "Class"].to_numpy(), df.loc[:, "Class"].to_numpy() 
X_ovsld, y_ovsld = sm.fit_resample(X, y)
X = np.concatenate((np.expand_dims(y_ovsld, 1), X_ovsld), axis=1)
df = pd.DataFrame(X, columns=df.columns)
df.head(5)
# Out:
#       Class       apol       ASA+       ASA- a_count a_donacc a_heavy a_hyd  \
# 0   Class 2  41.283001  21.282999  622.40619    43.0      0.0    43.0  40.0
# 1   Class 2  22.934343  155.97543  156.69504    18.0      0.0    10.0  10.0
# 2  Class -2  42.919998  38.976181   499.5217    22.0      0.0    22.0  22.0
# 3  Class -2  38.509171  46.270092  421.43369    23.0      1.0    19.0  16.0
# 4  Class -2  41.406792  56.392834  480.49115    22.0      0.0    21.0  21.0
#
#         a_IC  a_nC  ...        VSA    vsa_acc    vsa_hyd    vsa_pol   vsurf_A  \
# 0  49.644451  14.0  ...  421.45898  27.133842  357.37701  27.133842  3.610454
# 1  17.839369  10.0  ...  151.37508        0.0  130.88504        0.0   0.04012
# 2  21.868664  12.0  ...  338.42563        0.0  345.43402        0.0  0.048171
# 3  38.822643  10.0  ...  293.98846   2.503756  263.09042   2.503756  4.973507
# 4   26.55862  12.0  ...  330.35486        0.0  327.14081        0.0  0.137724
#
# ...

# %% [markdown]
# On confirme que les classes -2, 1 et 0 sont ré-équilibrées.

# %%
df["Class"].explode().value_counts()
# Out:
# Class -1    56
# Class -2    48
# Class 1     48
# Class 0     48
# Class 2      2
# Name: Class, dtype: int64

# %% [markdown]
# Comme mentionné précédemment, les variables respectent des échelles de grandeur très différentes.
# Il faut donc les centrer et les réduire.

# %%
from sklearn.preprocessing import StandardScaler

# On copie le dataframe (sans les étiquettes) dans une matrice numpy X
X = df.loc[:, df.columns != "Class"].to_numpy(dtype=np.float32)
y = df.loc[:, "Class"]
# On applique un centrage et une réduction par équart-type de la matrice X
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
df_scaled = df.copy()
df_scaled[num_cols] = scaler.fit_transform(df[num_cols])

# On valide la dernière étape en s'assurant que les moyennes et écart-types 
# soient égaux à 0 et 1 respectivement
assert np.allclose(0., X_scaled.mean(axis=0), atol=1e-6), "Moyennes non centrées"
assert np.allclose(1., X_scaled.std(axis=0), atol=1e-6), "Écart-types différents de 1"

# %% [markdown]
# ### Sélection des 10 meilleurs attributs
# Nous sélectionnons les 10 meilleurs attributs à l'aide d'une méthode ensembliste (ensemble methods). Cette technique n'a pas été étudiée en classe, mais elle est commune en machine learning. On combine la sortie de plusieurs algorithmes différents pour obtenir de meilleurs résultats. On considère quatre algorithmes différents: SelectKBest basé sur l'entropie différentielle, un arbre de décision et finalement les deux algorithmes de gradient boosting les plus populaires (XGBoost et Catboost). On calcule l'union des 10 attributs retenus par chaque méthode et on sélectionne les 10 attributs qui reviennent le plus fréquemment.

# %%
from sklearn.feature_selection import mutual_info_classif, SelectKBest
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from collections import Counter

# SelectKBest
clf = SelectKBest(mutual_info_classif, k=10)
clf.fit(df_scaled[num_cols], y)
features_a = list(clf.get_feature_names_out())

# DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion="entropy", random_state=42, max_features=10)
clf.fit(X_scaled, y)
ind = np.argpartition(clf.feature_importances_, -10)[-10:]
features_b = list(df.columns[ind])

# CatBoostClassifier
clf = CatBoostClassifier(verbose=False)
clf.fit(X_scaled, y)
ind = np.argpartition(clf.feature_importances_, -10)[-10:]
features_c = list(df.columns[ind])

# XGboost
clf = XGBClassifier()
clf.fit(X_scaled, y)
ind = np.argpartition(clf.feature_importances_, -10)[-10:]
features_d = list(df.columns[ind])

def default_value():
    return 0

all_features = features_a + features_b + features_c + features_d
features_dict = Counter(all_features)
features_df = pd.DataFrame(
    list(zip(features_dict.keys(), features_dict.values())),
    columns=["Attribut", "Décompte"]
).sort_values(ascending=False, by="Décompte")
features_df
# Out:
# [11:58:22] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\verdi\anaconda3\envs\anomaly_detection\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
#    Attribut  Décompte
# 18     chi1         3
# 22     a_nC         2
# 11    CASA+         2
# 16     chi0         2
# 15   chi1_C         2
# 13  vsa_pol         2
# 6        mr         2
# ...

# %% [markdown]
# Nous sommes chanceux et ne devons pas gérer le cas où le 11e attribut apparaît aussi souvent que le 10e. On peut finalement sauvegarder nos données.

# %%
selected_features = features_df.loc[:, "Attribut"][0:10].tolist()
X = df_scaled.loc[:, selected_features].to_numpy(dtype=np.float32)
df_final = pd.DataFrame(
    df_scaled.loc[:, selected_features + ["Class"]],
    index=df_scaled.index,
    columns=selected_features + ["Class"]
)
df_final.to_csv("./QSAR_10best_dataset.csv", index=False)
df_final.loc[:, selected_features] = df_final.loc[:, selected_features].astype(float)
selected_features
# Out:
# ['chi1',
#  'a_nC',
#  'CASA+',
#  'chi0',
#  'chi1_C',
#  'vsa_pol',
#  'mr',
#  'rgyr',
#  'SlogP',
#  'a_hyd']

# %% [markdown]
# ## Analyse de la corrélation
# Maintenant que les données sont prétraitées, on peut s'attarder à l'analyse des corrélations. Le premier graphique affiche les corrélations pour toutes les variables tandis que le second affiche les corrélations des attributs pour chacune des classe.

# %%
# Code inspiré de https://seaborn.pydata.org/examples/many_pairwise_correlations.html
# Pour simplifier l'anal, on calcule la matrice de covariance absolue.
# Ainsi, les cases bleues indiquent une absence de corrélation et les cases rouges l'inverse.
corr_mat = df_scaled[selected_features].corr().abs()
# On masque le haut de la matrice diagonale
mask = np.triu(np.ones_like(corr_mat, dtype=bool))
f, ax = plt.subplots(figsize=(12, 8))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(corr_mat, annot=False, cmap="BuPu")
# Out:
# <AxesSubplot:>

# %%
classes = list(set(df_scaled.loc[:, "Class"]))

f, axs = plt.subplots(3, 2, figsize=(12, 12))

f.tight_layout(pad=5)
for i, c in enumerate(classes):
    k = i // 2
    j = int(i % 2 != 0)
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    corr_mat = df_scaled[(df_scaled.Class ==  c)].loc[:, selected_features].corr().abs()
    axs[k, j].set_title(c)
    sns.heatmap(corr_mat, annot=False, cmap="BuPu", ax=axs[k, j])

# %% [markdown]
# On constate que les données ne sont pas corrélées de la même manière en fonction des classes. Les variables sont fortement corrélées pour la classe -2. L'attribut vsurf_R demeure le plus consistant avec le moins de corrélation cumulative entre les classes. Seule la classe 2 présente une corrélation non négligeable pour cet attribut. La présence de corrélation rend l'analyse par composantes principales pertinente car il sera possible de trouver des axes préservant cette corrélation.

# %% [markdown]
# Nous procédons maintenant à une réduction de dimension par ACP. Nous n'utilisons pas la librairie SKLearn mais effectuons plutôt les calculs manuellement pour des fins éducatives.

# %%
# Création de la matrice de corélation
Sigma = (1 / (len(df))) * (X.T @ X)
# Vérification que la diagonale de la matrice de corélation est contient des uns.
assert np.allclose(np.diag(Sigma), np.ones(Sigma.shape[0]), atol=1e-6)

# Décomposition valeurs, vecteurs propres
eig_vals, eig_vecs = np.linalg.eig(Sigma)
# Trier les vecteurs et valeurs propres de manière décroissante
# https://stackoverflow.com/questions/8092920/sort-eigenvalues-and-associated-eigenvectors-after-using-numpy-linalg-eig-in-pyt
idx = eig_vals.argsort()[::-1]   
eig_vals = eig_vals[idx]
eig_vecs = eig_vecs[:, idx]

# D'abord on calcule la somme de chaque valeur propre
sum_eigval = np.sum(eig_vals)
# Ensuite, on divise chacune des valeur propre par cette somme
var_prop = eig_vals / sum_eigval
cum_prop = np.cumsum(var_prop)
# Validation que la somme des proportions donne bien 1
assert(np.allclose(var_prop.sum(), 1))

# On crée une table pour présenter les résultats
d = {"Valeur propre": eig_vals, "Pourcentages": np.around(var_prop * 100, 4), "Pourcentages cumulés": np.around(cum_prop * 100, 4)}
eig_df = pd.DataFrame(data=d)
eig_df.head(10)
# Out:
#    Valeur propre  Pourcentages  Pourcentages cumulés
# 0       4.436629     44.366299             44.366299
# 1       3.286574     32.865700             77.232002
# 2       1.340024     13.400200             90.632301
# 3       0.605287      6.052900             96.685097
# 4       0.164628      1.646300             98.331398
# 5       0.113867      1.138700             99.470100
# 6       0.027512      0.275100             99.745201
# 7       0.020354      0.203500             99.948799
# 8       0.003615      0.036200             99.984901
# 9       0.001509      0.015100            100.000000

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x_labels = [i + 1 for i in range(len(var_prop))]

ax.plot(x_labels[0:15], var_prop[0:15], marker='o', markersize=6, color='blue', linewidth=2, label="Proportion de la variance")
ax.plot(x_labels[0:15], cum_prop[0:15], marker='o', color='orange', linewidth=2, label="Variance cumulée")
ax.legend()
ax.set_xticks(x_labels[0:15])
ax.set_title("Diagramme d'éboulis")
ax.set_xlabel("Composante principale")
ax.set_ylabel("Proportion de variance")
plt.show()

# %% [markdown]
# Le diagramme d'éboulis ainsi que le tableau des composantes principales nous informent que 86% de la corrélation est expliquée par seulement
# les trois premières composantes principales. On projette donc nos données sur ces trois composantes. Il y a une différence de 10% entre la deuxième et la troisième composante. Par conséquent, la projection 3CP est favorisée quoique 2CP suffirait probablement avec 76% de corrélation variance cumulée.

# %%
M = 3
Pi = eig_vecs[:, 0:M]
Z = X @ Pi
X_hat = Z @ Pi.T
assert X_hat.shape == X.shape, "mauvais format de matrice"

# %%
df_acp = pd.DataFrame(
    np.concatenate((Z, np.expand_dims(y, 1)), axis=1),
    columns=["CP-{}".format(i+1) for i in range(M)] + ["Class"],
)
df_acp = df_acp.astype({"CP-1": "float", "CP-2": "float", "CP-3": "float"})
df_acp.to_csv("./QSAR_ACP_dataset.csv", index=False)
df_acp.head(5)
# Out:
#        CP-1      CP-2      CP-3     Class
# 0 -7.582298 -3.831741 -2.126414   Class 2
# 1  4.046257  0.349430  0.522917   Class 2
# 2 -2.421048  0.747139  0.838298  Class -2
# 3  0.420803 -0.361161  0.867845  Class -2
# 4 -2.002030  0.773245  0.678125  Class -2

# %% [markdown]
# On affiche maintenant chacune des paires des variables afin de vérifier si une paire permet de bien distinguer des nuages de points.

# %%
sns.pairplot(df_acp, hue="Class")

# %% [markdown]
# Malheureusement, les clusters demeurent fortement entremêlés.

# %% [markdown]
# ## Calcul des centroids
# Pour confirmer le choix entre 3CP et 2CP, on vérifie les performances d'un classifieur. Ce classifieur assigne à une observation la classe du centroid dont il est le plus proche. Afficher centroids (représentés par moyenne arithémtique) de chaque composante principale pour chaque classe. On commence par afficher les centroids - représentés par la moyenne arithmétique - de chaque composante principale pour chacune des classes.

# %%
from sklearn.preprocessing import LabelEncoder
from models import NearestCentroid

y_true = df_acp.loc[:, "Class"].to_numpy()
le = LabelEncoder()
y_true_enc = le.fit_transform(y_true)

# %%
df_centroids = df_acp.groupby("Class").mean()
acp_num_cols = df_acp.select_dtypes(exclude=object).columns.tolist()
df_centroids
# Out:
#               CP-1      CP-2      CP-3
# Class
# Class -1 -0.457546  0.287130  0.173946
# Class -2 -1.606662  0.628402  0.611154
# Class 0   0.207221  0.048556 -0.621749
# Class 1   2.006912 -0.939395 -0.158936
# Class 2  -1.768020 -1.741156 -0.801749

# %% [markdown]
# On peut maintenant entraîner le classifieur sur les données.

# %%
def mahalanobis(X: np.array, mu: np.array, S: np.array):
    S_inv = np.linalg.inv(S)
    return (X - mu).T @ S_inv @ (X - mu)

def nearest_centroid_classifier(data: np.array, targets, label_enc, dist_measure="euclidean"):
    clf = NearestCentroid(label_encoder=label_enc, metric=dist_measure)
    clf.fit(data, targets)
    y_pred = clf.predict(data)
    return clf.evaluate(targets, y_pred)

# %%
# Transfert des données réduites dans une liste numpy
data = df_acp.loc[:, acp_num_cols].to_numpy()

# Entraînement du classifieur sur les données représentées respectivement par 
# deux et trois composantes principales
df_metrics_3cp = nearest_centroid_classifier(data, y_true, le)
df_metrics_2cp = nearest_centroid_classifier(data[:, 0:2], y_true, le)
f, axs = plt.subplots(1, 3, figsize=(24, 12))

# On sauvegarde les métriques de performance dans des DataFrame
df_precision = pd.concat([
    df_metrics_2cp.loc["precision"][0:5].rename("2-CP"), 
    df_metrics_3cp.loc["precision"][0:5].rename("3-CP")
], axis=1)
df_recall = pd.concat([
    df_metrics_2cp.loc["recall"][0:5].rename("2-CP"), 
    df_metrics_3cp.loc["recall"][0:5].rename("3-CP")
], axis=1)
df_f1 = pd.concat([
    df_metrics_2cp.loc["f1-score"][0:5].rename("2-CP"), 
    df_metrics_3cp.loc["f1-score"][0:5].rename("3-CP")
], axis=1)

# Affichage
df_precision.plot(kind="barh", ax=axs[0])
df_recall.plot(kind="barh", ax=axs[1])
df_f1.plot(kind="barh", ax=axs[2])

axs[0].set_title("Precision")
axs[0].set_xticks(np.arange(0, 1, step=0.1))
axs[1].set_title("Recall")
axs[2].set_title("F1-score")

plt.show()

# %% [markdown]
# On constate que la precision, recall (et par extension le f1-score) sont systématiquement supérieurs pour le cas 3CP. Ce résultat n'est pas surprenant considérant que les trois composantes principales contiennent plus d'information que seulement deux composantes. On affiche maintenant les performances exactes pour le 3CP.

# %%
df_metrics_3cp.loc[:, classes]
# Out:
#             Class -1   Class 2   Class -2    Class 0  Class 1
# precision   0.555556  0.058824   0.700000   0.695652     0.75
# recall      0.535714  0.500000   0.875000   0.333333     0.75
# f1-score    0.545455  0.105263   0.777778   0.450704     0.75
# support    56.000000  2.000000  48.000000  48.000000    48.00
